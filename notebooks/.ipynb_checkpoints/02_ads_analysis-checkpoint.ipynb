# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ads = pd.read_csv('../data/raw/global_ads_performance_dataset.csv')
ads['date'] = pd.to_datetime(ads['date'])
ads['month'] = ads['date'].dt.to_period('M')
print("Data loaded ✅", ads.shape)
# Out:
# Data loaded ✅ (1800, 15)

# %%
platform_summary = ads.groupby('platform').agg(
    total_spend=('ad_spend', 'sum'),
    total_impressions=('impressions', 'sum'),
    total_clicks=('clicks', 'sum'),
    total_conversions=('conversions', 'sum'),
    avg_ROAS=('ROAS', 'mean'),
    avg_CTR=('CTR', 'mean'),
    avg_CPC=('CPC', 'mean'),
    avg_CPA=('CPA', 'mean')
).round(2)

platform_summary['conversion_rate'] = (platform_summary['total_conversions'] / platform_summary['total_clicks'] * 100).round(2)
print(platform_summary)
# Out:
#             total_spend  total_impressions  total_clicks  total_conversions  \
# platform
# Google Ads   6349268.91           73801150       2936149             131098
# Meta Ads     2106061.67           64403494       1596736              73262
# TikTok Ads   2653418.51           47049590       2599931             122452
#
#             avg_ROAS  avg_CTR  avg_CPC  avg_CPA  conversion_rate
# platform
# Google Ads      4.11     0.04     2.15    64.06             4.46
# Meta Ads        6.92     0.02     1.32    39.10             4.59
# TikTok Ads      9.54     0.05     1.01    29.20             4.71

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('UA Channel Performance Analysis', fontsize=16, fontweight='bold')

colors = ['#4285F4', '#1877F2', '#000000']

# ROAS
axes[0,0].bar(platform_summary.index, platform_summary['avg_ROAS'], color=colors)
axes[0,0].set_title('Average ROAS by Platform')
axes[0,0].set_ylabel('ROAS')
for i, v in enumerate(platform_summary['avg_ROAS']):
    axes[0,0].text(i, v + 0.1, str(v), ha='center', fontweight='bold')

# CPA
axes[0,1].bar(platform_summary.index, platform_summary['avg_CPA'], color=colors)
axes[0,1].set_title('Average CPA by Platform (lower = better)')
axes[0,1].set_ylabel('CPA ($)')
for i, v in enumerate(platform_summary['avg_CPA']):
    axes[0,1].text(i, v + 0.5, str(v), ha='center', fontweight='bold')

# Spend vs Conversions
axes[1,0].scatter(platform_summary['total_spend'], platform_summary['total_conversions'], 
                  s=200, c=colors, zorder=5)
for i, platform in enumerate(platform_summary.index):
    axes[1,0].annotate(platform, (platform_summary['total_spend'][i], 
                       platform_summary['total_conversions'][i]), 
                       textcoords="offset points", xytext=(10,5))
axes[1,0].set_title('Total Spend vs Total Conversions')
axes[1,0].set_xlabel('Total Spend ($)')
axes[1,0].set_ylabel('Total Conversions')

# Monthly spend trend
monthly_spend = ads.groupby(['month', 'platform'])['ad_spend'].sum().unstack()
monthly_spend.plot(ax=axes[1,1], marker='o')
axes[1,1].set_title('Monthly Ad Spend Trend by Platform')
axes[1,1].set_ylabel('Ad Spend ($)')
axes[1,1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('../images/02_ads_analysis.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart saved ✅")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('UA Channel Performance Analysis', fontsize=16, fontweight='bold')

colors = ['#4285F4', '#1877F2', '#000000']
platforms = platform_summary.index.tolist()

# ROAS
axes[0,0].bar(platforms, platform_summary['avg_ROAS'].values, color=colors)
axes[0,0].set_title('Average ROAS by Platform')
axes[0,0].set_ylabel('ROAS')
for i, v in enumerate(platform_summary['avg_ROAS'].values):
    axes[0,0].text(i, v + 0.1, str(round(v,2)), ha='center', fontweight='bold')

# CPA
axes[0,1].bar(platforms, platform_summary['avg_CPA'].values, color=colors)
axes[0,1].set_title('Average CPA by Platform (lower = better)')
axes[0,1].set_ylabel('CPA ($)')
for i, v in enumerate(platform_summary['avg_CPA'].values):
    axes[0,1].text(i, v + 0.5, str(round(v,2)), ha='center', fontweight='bold')

# Spend vs Conversions
spend_vals = platform_summary['total_spend'].values
conv_vals = platform_summary['total_conversions'].values
axes[1,0].scatter(spend_vals, conv_vals, s=200, c=colors, zorder=5)
for i, platform in enumerate(platforms):
    axes[1,0].annotate(platform, (spend_vals[i], conv_vals[i]),
                       textcoords="offset points", xytext=(10,5))
axes[1,0].set_title('Total Spend vs Total Conversions')
axes[1,0].set_xlabel('Total Spend ($)')
axes[1,0].set_ylabel('Total Conversions')

# Monthly spend trend
monthly_spend = ads.groupby(['month', 'platform'])['ad_spend'].sum().unstack()
monthly_spend.plot(ax=axes[1,1], marker='o')
axes[1,1].set_title('Monthly Ad Spend Trend by Platform')
axes[1,1].set_ylabel('Ad Spend ($)')
axes[1,1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('../images/02_ads_analysis.png', dpi=150, bbox_inches='tight')
plt.show()
print("Chart saved ✅")
# Out:
# Chart saved ✅

# %% [markdown]
# ## 💡 Business Insights — UA Channel Analysis
#
# ### Key Findings:
# 1. **TikTok Ads** delivers the highest ROAS (9.54x) at the lowest CPA ($29.2)
#    → Most cost-efficient channel for user acquisition
#
# 2. **Google Ads** is underperforming: highest spend ($6.3M) but lowest ROAS (4.11x) and highest CPA ($64)
#    → Currently over-investing in the least efficient channel
#
# 3. **Meta Ads** shows the most balanced performance: ROAS 6.92x, CPA $39.1
#    → Stable channel, suitable for scaling
#
# ### Recommendations:
# - 🔴 Reduce Google Ads budget by 20-30%
# - 🟢 Scale TikTok Ads — highest ROAS with room to grow
# - 🟡 Maintain Meta Ads — consistent and stable performance
# - 📊 Monitor CTR and CPC weekly to detect anomalies early
